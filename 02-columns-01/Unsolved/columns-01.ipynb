# %% [markdown]
# # Column Manipulation of Pandas DataFrames

# %% [markdown]
# ### 1. Import libraries and dependencies

# %%
# Import pandas, pathlib, and numpy libraries
from pathlib import Path
import pandas as pd
import numpy as np

# %% [markdown]
# ### 2. Create a Path to the File Using Pathlib

# %%
csvpath = Path("../Resources/people.csv")

# %% [markdown]
# ### 3. Read the CSV into a Pandas DataFrame and Display a Few Rows

# %%
# Use the file path to read the CSV into a DataFrame and display a few rows
df = pd.read_csv(csvpath, index_col = 'id')
df.head()
# Out:
#     first_name    last_name                            email  gender  \
# id
# 1.0    Keriann    Lenormand  klenormand0@businessinsider.com  Female
# 2.0    Huntley        Rupke              hrupke1@reuters.com    Male
# 3.0     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 4.0     Cullie          NaN               cputten3@nymag.com    Male
# 5.0      Ariel    Strangman       astrangman4@bravesites.com  Female
#
#                                               uni_grad           job_title  \
# id
# 1.0                                  Aurora University  Nurse Practicioner
# 2.0                      Osaka University of Economics     Project Manager
# 3.0                                  Ludong University  Environmental Tech
# 4.0  Université des Sciences et de la Technologie d...     Legal Assistant
# 5.0                             Boise State University     Project Manager
#
#       Income
# id
# 1.0  58135.0
# 2.0  96053.0
# 3.0  59196.0
# 4.0  88493.0
# 5.0  89073.0

# %% [markdown]
# ### 4. View Columns Names

# %%
# Use the `columns` attribute to output the column names
df.columns
# Out:
# Index(['first_name', 'last_name', 'email', 'gender', 'uni_grad', 'job_title',
#        'Income'],
#       dtype='object')

# %%
df.describe(include='all')
# Out:
#        first_name last_name                 email gender  \
# count         993       990                   992    998
# unique        914       974                   991      2
# top       Ailbert    Raveau  ayang@codedrills.com   Male
# freq            3         2                     2    508
# mean          NaN       NaN                   NaN    NaN
# std           NaN       NaN                   NaN    NaN
# min           NaN       NaN                   NaN    NaN
# 25%           NaN       NaN                   NaN    NaN
# 50%           NaN       NaN                   NaN    NaN
# 75%           NaN       NaN                   NaN    NaN
# max           NaN       NaN                   NaN    NaN
#
#                       uni_grad              job_title         Income
# count                      991                    998     998.000000
# unique                     939                    183            NaN
# top     University of Portland  Chief Design Engineer            NaN
# freq                         3                     16            NaN
# mean                       NaN                    NaN   84691.693387
# std                        NaN                    NaN   20185.664319
# min                        NaN                    NaN   50013.000000
# 25%                        NaN                    NaN   67353.000000
# 50%                        NaN                    NaN   84296.000000
# 75%                        NaN                    NaN  102374.750000
# max                        NaN                    NaN  119987.000000

# %% [markdown]
# ### 5. View Column Data Types

# %%
# Use the `dtypes` attribute to output the column names and data
df.dtypes
# Out:
# Person_ID      object
# First_Name     object
# Email          object
# Gender         object
# University     object
# Occupation     object
# Salary        float64
# dtype: object

# %% [markdown]
# ### 6. Rename Columns Using List

# %%
# Set the `columns` attribute to a new list of column names
columns = ["Person_ID", "First_Name", "Last_Name", "Email", "Gender", "University", "Occupation", "Salary"]
df.columns = columns

df.head()
# Out:
#     Person_ID   First_Name                        Last_Name   Email  \
# id
# 1.0   Keriann    Lenormand  klenormand0@businessinsider.com  Female
# 2.0   Huntley        Rupke              hrupke1@reuters.com    Male
# 3.0    Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 4.0    Cullie          NaN               cputten3@nymag.com    Male
# 5.0     Ariel    Strangman       astrangman4@bravesites.com  Female
#
#                                                 Gender          University  \
# id
# 1.0                                  Aurora University  Nurse Practicioner
# 2.0                      Osaka University of Economics     Project Manager
# 3.0                                  Ludong University  Environmental Tech
# 4.0  Université des Sciences et de la Technologie d...     Legal Assistant
# 5.0                             Boise State University     Project Manager
#
#      Occupation  Salary
# id
# 1.0     58135.0      35
# 2.0     96053.0      44
# 3.0     59196.0      28
# 4.0     88493.0      50
# 5.0     89073.0      51

# %% [markdown]
# ### 7. Rename Columns Using Dictionary

# %%
df =df.rename(columns ={ "id":"Person_ID", "first_name": "First_Name", "last_name":"Last_Name","email": "Email", "gender":"Gender", "uni_grad":"University", "job_title" :"Occupation", "Income":"Salary" })
df.head()
# Out:
#     Person_ID   First_Name                        Last_Name   Email  \
# id
# 1.0   Keriann    Lenormand  klenormand0@businessinsider.com  Female
# 2.0   Huntley        Rupke              hrupke1@reuters.com    Male
# 3.0    Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 4.0    Cullie          NaN               cputten3@nymag.com    Male
# 5.0     Ariel    Strangman       astrangman4@bravesites.com  Female
#
#                                                 Gender          University  \
# id
# 1.0                                  Aurora University  Nurse Practicioner
# 2.0                      Osaka University of Economics     Project Manager
# 3.0                                  Ludong University  Environmental Tech
# 4.0  Université des Sciences et de la Technologie d...     Legal Assistant
# 5.0                             Boise State University     Project Manager
#
#      Occupation  Salary
# id
# 1.0     58135.0      35
# 2.0     96053.0      44
# 3.0     59196.0      28
# 4.0     88493.0      50
# 5.0     89073.0      51

# %%
# Use the `rename` function and set the `columns` parameter to a dictionary of new column names
df = df.rename(columns={"id": "Person_ID","first_name": "First_Name","last_name": "Last_Name","email": "Email","gender": "Gender","uni_grad": "University","job_title": "Occupation","Income": "Salary"})

df.head()
# Out:
#     Person_ID                        Last_Name   First_Name  \
# id
# 1.0   Keriann  klenormand0@businessinsider.com    Lenormand
# 2.0   Huntley              hrupke1@reuters.com        Rupke
# 3.0    Gorden      gdalgarnowch2@microsoft.com  Dalgarnowch
# 4.0    Cullie               cputten3@nymag.com          NaN
# 5.0     Ariel       astrangman4@bravesites.com    Strangman
#
#                                                 Gender          University  \
# id
# 1.0                                  Aurora University  Nurse Practicioner
# 2.0                      Osaka University of Economics     Project Manager
# 3.0                                  Ludong University  Environmental Tech
# 4.0  Université des Sciences et de la Technologie d...     Legal Assistant
# 5.0                             Boise State University     Project Manager
#
#      Occupation  Salary   Email  Age  Age_Copy
# id
# 1.0     58135.0      35  Female   55        45
# 2.0     96053.0      44    Male   49        37
# 3.0     59196.0      28    Male   22        47
# 4.0     88493.0      50    Male   50        23
# 5.0     89073.0      51  Female   25        36

# %% [markdown]
# ### 8. Re-order Columns

# %%
# Use a list of re-ordered column names to alter the column order of the original DataFrame
df = df[["Person_ID","Last_Name", "First_Name","Gender","University", "Occupation", "Salary", "Email"]]
df.head()
# Out:
#     Person_ID                        Last_Name   First_Name  \
# id
# 1.0   Keriann  klenormand0@businessinsider.com    Lenormand
# 2.0   Huntley              hrupke1@reuters.com        Rupke
# 3.0    Gorden      gdalgarnowch2@microsoft.com  Dalgarnowch
# 4.0    Cullie               cputten3@nymag.com          NaN
# 5.0     Ariel       astrangman4@bravesites.com    Strangman
#
#                                                 Gender          University  \
# id
# 1.0                                  Aurora University  Nurse Practicioner
# 2.0                      Osaka University of Economics     Project Manager
# 3.0                                  Ludong University  Environmental Tech
# 4.0  Université des Sciences et de la Technologie d...     Legal Assistant
# 5.0                             Boise State University     Project Manager
#
#      Occupation  Salary   Email
# id
# 1.0     58135.0      35  Female
# 2.0     96053.0      44    Male
# 3.0     59196.0      28    Male
# 4.0     88493.0      50    Male
# 5.0     89073.0      51  Female

# %% [markdown]
# ### 9. Create Additional Column

# %%
# Use the `randint` function to randomly generate an `Age` from 22 to 65 for 1000 rows
# Use the `randint` function to randomly generate an `Age` from 22 to 65 for 1000 rows

df["Age"] = np.random.randint(low=22, high=65, size=1000)
df["Age_Copy"] = np.random.randint(low=22, high=65, size=1000)
df.head()
# Out:
#     Person_ID                        Last_Name   First_Name  \
# id
# 1.0   Keriann  klenormand0@businessinsider.com    Lenormand
# 2.0   Huntley              hrupke1@reuters.com        Rupke
# 3.0    Gorden      gdalgarnowch2@microsoft.com  Dalgarnowch
# 4.0    Cullie               cputten3@nymag.com          NaN
# 5.0     Ariel       astrangman4@bravesites.com    Strangman
#
#                                                 Gender          University  \
# id
# 1.0                                  Aurora University  Nurse Practicioner
# 2.0                      Osaka University of Economics     Project Manager
# 3.0                                  Ludong University  Environmental Tech
# 4.0  Université des Sciences et de la Technologie d...     Legal Assistant
# 5.0                             Boise State University     Project Manager
#
#      Occupation  Salary   Email  Age  Age_Copy
# id
# 1.0     58135.0      35  Female   55        45
# 2.0     96053.0      44    Male   49        37
# 3.0     59196.0      28    Male   22        47
# 4.0     88493.0      50    Male   50        23
# 5.0     89073.0      51  Female   25        36

# %% [markdown]
# ### 10. Delete Columns

# %%
# Use the `drop` function to delete the newly created `Age` column
df = df.drop(columns=["Age_Copy"])
df.head()
# Out:
#     first_name    last_name                            email  gender  \
# id
# 1.0    Keriann    Lenormand  klenormand0@businessinsider.com  Female
# 2.0    Huntley        Rupke              hrupke1@reuters.com    Male
# 3.0     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 4.0     Cullie          NaN               cputten3@nymag.com    Male
# 5.0      Ariel    Strangman       astrangman4@bravesites.com  Female
#
#                                               uni_grad           job_title  \
# id
# 1.0                                  Aurora University  Nurse Practicioner
# 2.0                      Osaka University of Economics     Project Manager
# 3.0                                  Ludong University  Environmental Tech
# 4.0  Université des Sciences et de la Technologie d...     Legal Assistant
# 5.0                             Boise State University     Project Manager
#
#       Income  Age
# id
# 1.0  58135.0   35
# 2.0  96053.0   44
# 3.0  59196.0   28
# 4.0  88493.0   50
# 5.0  89073.0   51

# %% [markdown]
# ### 11. Save Modified DataFrame to New CSV

# %%
# Save the DataFrame to the `Resources` folder
df.to_csv("../Resources/people_reordered.csv")
